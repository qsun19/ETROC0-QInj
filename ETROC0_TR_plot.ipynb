# %%
import os, sys
import h5py
import numpy as np
import pandas as pd
from scipy.interpolate import InterpolatedUnivariateSpline
from scipy import optimize
import matplotlib.pyplot as plt
from scipy import integrate
from scipy.optimize import curve_fit
from scipy.stats import norm
import matplotlib.font_manager as font_manager
from tqdm.autonotebook import tqdm
from matplotlib.backends.backend_pdf import PdfPages
import time
from scipy.optimize import curve_fit
from scipy.stats import norm
from scipy import stats
import scipy.stats

import etroc0_benchtest
# Out:
# C:\Users\qsun\AppData\Local\Continuum\anaconda3\lib\site-packages\tqdm\autonotebook.py:17: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
TR_DGDP=[29.93, 23.99, 21.10]
DAC_DGDP=[9, 15, 21]

TR_DGHP=[20.32, 21.04, 16.88]
DAC_DGHP=[9, 13, 18]

TR_LGDP=[29.41, 24.82, 23.62]
DAC_LGDP=[9, 13, 18]

TR_HGDP=[41.74, 39.47, 32.05]
DAC_HGDP=[9, 15, 25]

fig2,ax2 = plt.subplots(dpi=200)
ax2.plot(DAC_DGDP, TR_DGDP, 'o-', linewidth=2,  label="DGDP")
ax2.plot(DAC_DGHP, TR_DGHP, 'o-', linewidth=2,  label="DGHP")
ax2.plot(DAC_LGDP, TR_LGDP, 'o-', linewidth=2,  label="LGDP")
ax2.plot(DAC_HGDP, TR_HGDP, 'o-', linewidth=2,  label="HGDP")

ax2.set(xlabel='DAC over baseline', ylabel='time resolution(ps)',
       title='time resolution vs threshold')
# ax2.set_ylim(bottom=20,top=160)
ax2.grid(which='both')
ax2.legend(loc = 'best', fontsize = 'small')
plt.show()
